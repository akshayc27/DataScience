# %%
import pandas as pd
import matplotlib.pyplot as plt
import re
import time
import warnings
import sqlite3
from sqlalchemy import create_engine # database connection
import csv
import os
warnings.filterwarnings("ignore")
import datetime as dt
import numpy as np
from nltk.corpus import stopwords
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import normalize
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.manifold import TSNE
import seaborn as sns
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score, log_loss
from sklearn.feature_extraction.text import TfidfVectorizer
from collections import Counter
from scipy.sparse import hstack
from sklearn.multiclass import OneVsRestClassifier
from sklearn.svm import SVC
from sklearn.model_selection import StratifiedKFold 
from collections import Counter, defaultdict
from sklearn.calibration import CalibratedClassifierCV
from sklearn.naive_bayes import MultinomialNB
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.model_selection import GridSearchCV
import math
from sklearn.metrics import normalized_mutual_info_score
from sklearn.ensemble import RandomForestClassifier



from sklearn.model_selection import cross_val_score
from sklearn.linear_model import SGDClassifier
#from mlxtend.classifier import StackingClassifier

from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import precision_recall_curve, auc, roc_curve

# %%
cd  "/content/drive/MyDrive/DataScience\MachineLearning"
# Out:
# /content/drive/MyDrive/DataScience\MachineLearning

# %% [markdown]
# # ***Reading data from file *** **bold text**

# %%
data= pd.read_csv("final_features.csv",nrows=50000)

# %%
data.head()
# Out:
#    Unnamed: 0  id  is_duplicate  ...        93_y        94_y       95_y
# 0           0   0             0  ...   99.282776   50.791731 -17.566246
# 1           1   1             0  ...  194.269546  128.207803  55.490061
# 2           2   2             0  ...   19.922719   21.266690  49.574858
# 3           3   3             0  ...  -14.231000    4.772115   7.711628
# 4           4   4             0  ...   22.118795   68.802072  21.025373
#
# [5 rows x 221 columns]

# %%
data.drop(data.index[0], inplace=True)
y_true = data['is_duplicate']
data.drop(['Unnamed: 0', 'id','is_duplicate'], axis=1, inplace=True)

# %%
data.head()
# Out:
#     cwc_min   cwc_max   csc_min  ...        93_y        94_y       95_y
# 1  0.799984  0.399996  0.749981  ...  194.269546  128.207803  55.490061
# 2  0.399992  0.333328  0.399992  ...   19.922719   21.266690  49.574858
# 3  0.000000  0.000000  0.000000  ...  -14.231000    4.772115   7.711628
# 4  0.399992  0.199998  0.999950  ...   22.118795   68.802072  21.025373
# 5  0.666656  0.571420  0.888879  ...  199.880774   68.090964  90.085963
#
# [5 rows x 218 columns]

# %% [markdown]
# <h2> 4.2 Converting strings to numerics </h2>

# %%
# after we read from sql table each entry was read it as a string
# we convert all the features into numaric before we apply any model
cols = list(data.columns)
for i in cols:
    data[i] = data[i].apply(pd.to_numeric)
    print(i)
# Out:
# cwc_min
# cwc_max
# csc_min
# csc_max
# ctc_min
# ctc_max
# last_word_eq
# first_word_eq
# abs_len_diff
# mean_len
# token_set_ratio
# token_sort_ratio
# fuzz_ratio
# fuzz_partial_ratio
# longest_substr_ratio
# freq_qid1
# freq_qid2
# q1len
# q2len
# q1_n_words
# q2_n_words
# word_Common
# word_Total
# word_share
# freq_q1+q2
# freq_q1-q2
# 0_x
# 1_x
# 2_x
# 3_x
# 4_x
# 5_x
# 6_x
# 7_x
# 8_x
# 9_x
# 10_x
# 11_x
# 12_x
# 13_x
# 14_x
# 15_x
# 16_x
# 17_x
# 18_x
# 19_x
# 20_x
# 21_x
# 22_x
# 23_x
# 24_x
# 25_x
# 26_x
# 27_x
# 28_x
# 29_x
# 30_x
# 31_x
# 32_x
# 33_x
# 34_x
# 35_x
# 36_x
# 37_x
# 38_x
# 39_x
# 40_x
# 41_x
# 42_x
# 43_x
# 44_x
# 45_x
# 46_x
# 47_x
# 48_x
# 49_x
# 50_x
# 51_x
# 52_x
# 53_x
# 54_x
# 55_x
# 56_x
# 57_x
# 58_x
# 59_x
# 60_x
# 61_x
# 62_x
# 63_x
# 64_x
# 65_x
# 66_x
# 67_x
# 68_x
# 69_x
# 70_x
# 71_x
# 72_x
# 73_x
# 74_x
# 75_x
# 76_x
# 77_x
# 78_x
# 79_x
# 80_x
# 81_x
# 82_x
# 83_x
# 84_x
# 85_x
# 86_x
# 87_x
# 88_x
# 89_x
# 90_x
# 91_x
# 92_x
# 93_x
# 94_x
# 95_x
# 0_y
# 1_y
# 2_y
# 3_y
# 4_y
# 5_y
# 6_y
# 7_y
# 8_y
# 9_y
# 10_y
# 11_y
# 12_y
# 13_y
# 14_y
# 15_y
# 16_y
# 17_y
# 18_y
# 19_y
# 20_y
# 21_y
# 22_y
# 23_y
# 24_y
# 25_y
# 26_y
# 27_y
# 28_y
# 29_y
# 30_y
# 31_y
# 32_y
# 33_y
# 34_y
# 35_y
# 36_y
# 37_y
# 38_y
# 39_y
# 40_y
# 41_y
# 42_y
# 43_y
# 44_y
# 45_y
# 46_y
# 47_y
# 48_y
# 49_y
# 50_y
# 51_y
# 52_y
# 53_y
# 54_y
# 55_y
# 56_y
# 57_y
# 58_y
# 59_y
# 60_y
# 61_y
# 62_y
# 63_y
# 64_y
# 65_y
# 66_y
# 67_y
# 68_y
# 69_y
# 70_y
# 71_y
# 72_y
# 73_y
# 74_y
# 75_y
# 76_y
# 77_y
# 78_y
# 79_y
# 80_y
# 81_y
# 82_y
# 83_y
# 84_y
# 85_y
# 86_y
# 87_y
# 88_y
# 89_y
# 90_y
# 91_y
# 92_y
# 93_y
# 94_y
# 95_y

# %% [markdown]
# <h2> 4.3 Random train test split( 70:30) </h2>

# %%
# https://stackoverflow.com/questions/7368789/convert-all-strings-in-a-list-to-int
y_true = list(map(int, y_true.values))

# %%
X_train,X_test, y_train, y_test = train_test_split(data, y_true, stratify=y_true, test_size=0.3)

# %%
print("Number of data points in train data :",X_train.shape)
print("Number of data points in test data :",X_test.shape)
# Out:
# Number of data points in train data : (34999, 218)
# Number of data points in test data : (15000, 218)

# %%
print("-"*10, "Distribution of output variable in train data", "-"*10)
train_distr = Counter(y_train)
train_len = len(y_train)
print("Class 0: ",int(train_distr[0])/train_len,"Class 1: ", int(train_distr[1])/train_len)
print("-"*10, "Distribution of output variable in test data", "-"*10)
test_distr = Counter(y_test)
test_len = len(y_test)
print("Class 0: ",int(test_distr[1])/test_len, "Class 1: ",int(test_distr[1])/test_len)
# Out:
# ---------- Distribution of output variable in train data ----------
# Class 0:  0.6270179147975656 Class 1:  0.37298208520243437
# ---------- Distribution of output variable in test data ----------
# Class 0:  0.373 Class 1:  0.373

# %%
# This function plots the confusion matrices given y_i, y_i_hat.
def plot_confusion_matrix(test_y, predict_y):
    C = confusion_matrix(test_y, predict_y)
    # C = 9,9 matrix, each cell (i,j) represents number of points of class i are predicted class j
    
    A =(((C.T)/(C.sum(axis=1))).T)
    #divid each element of the confusion matrix with the sum of elements in that column
    
    # C = [[1, 2],
    #     [3, 4]]
    # C.T = [[1, 3],
    #        [2, 4]]
    # C.sum(axis = 1)  axis=0 corresonds to columns and axis=1 corresponds to rows in two diamensional array
    # C.sum(axix =1) = [[3, 7]]
    # ((C.T)/(C.sum(axis=1))) = [[1/3, 3/7]
    #                           [2/3, 4/7]]

    # ((C.T)/(C.sum(axis=1))).T = [[1/3, 2/3]
    #                           [3/7, 4/7]]
    # sum of row elements = 1
    
    B =(C/C.sum(axis=0))
    #divid each element of the confusion matrix with the sum of elements in that row
    # C = [[1, 2],
    #     [3, 4]]
    # C.sum(axis = 0)  axis=0 corresonds to columns and axis=1 corresponds to rows in two diamensional array
    # C.sum(axix =0) = [[4, 6]]
    # (C/C.sum(axis=0)) = [[1/4, 2/6],
    #                      [3/4, 4/6]] 
    plt.figure(figsize=(20,4))
    
    labels = [1,2]
    # representing A in heatmap format
    cmap=sns.light_palette("blue")
    plt.subplot(1, 3, 1)
    sns.heatmap(C, annot=True, cmap=cmap, fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.title("Confusion matrix")
    
    plt.subplot(1, 3, 2)
    sns.heatmap(B, annot=True, cmap=cmap, fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.title("Precision matrix")
    
    plt.subplot(1, 3, 3)
    # representing B in heatmap format
    sns.heatmap(A, annot=True, cmap=cmap, fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.title("Recall matrix")
    
    plt.show()

# %% [markdown]
# <h2> 4.4 Building a random model (Finding worst-case log-loss) </h2>

# %%
# we need to generate 9 numbers and the sum of numbers should be 1
# one solution is to genarate 9 numbers and divide each of the numbers by their sum
# ref: https://stackoverflow.com/a/18662466/4084039
# we create a output array that has exactly same size as the CV data
predicted_y = np.zeros((test_len,2))
for i in range(test_len):
    rand_probs = np.random.rand(1,2)
    predicted_y[i] = ((rand_probs/sum(sum(rand_probs)))[0])
print("Log loss on Test Data using Random Model",log_loss(y_test, predicted_y, eps=1e-15))

predicted_y =np.argmax(predicted_y, axis=1)
plot_confusion_matrix(y_test, predicted_y)
# Out:
# Log loss on Test Data using Random Model 0.8969009036583594

# %% [markdown]
# <h2> 4.4 Logistic Regression with hyperparameter tuning </h2>

# %%
alpha = [10 ** x for x in range(-5, 2)] # hyperparam for SGD classifier.

log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(X_train, y_train)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(X_train, y_train)
    predict_y = sig_clf.predict_proba(X_test)
    log_error_array.append(log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, log_error_array,c='g')
for i, txt in enumerate(np.round(log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(X_train, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(X_train, y_train)

predict_y = sig_clf.predict_proba(X_train)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(X_test)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
predicted_y =np.argmax(predict_y,axis=1)
print("Total number of data points :", len(predicted_y))
plot_confusion_matrix(y_test, predicted_y)
# Out:
# For values of alpha =  1e-05 The log loss is: 0.6605330481991829
# For values of alpha =  0.0001 The log loss is: 0.46400664113776297
# For values of alpha =  0.001 The log loss is: 0.46808627054037705
# For values of alpha =  0.01 The log loss is: 0.46455211909191835
# For values of alpha =  0.1 The log loss is: 0.4656542195764152
# For values of alpha =  1 The log loss is: 0.4895790585216697
# For values of alpha =  10 The log loss is: 0.527079543929018
# For values of best alpha =  0.0001 The train log loss is: 0.4586089445542516
# For values of best alpha =  0.0001 The test log loss is: 0.46400664113776297
# Total number of data points : 15000

# %% [markdown]
# <h2> 4.5 Linear SVM with hyperparameter tuning </h2>

# %%
alpha = [10 ** x for x in range(-5, 2)] # hyperparam for SGD classifier.


log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l1', loss='hinge', random_state=42)
    clf.fit(X_train, y_train)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(X_train, y_train)
    predict_y = sig_clf.predict_proba(X_test)
    log_error_array.append(log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, log_error_array,c='g')
for i, txt in enumerate(np.round(log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l1', loss='hinge', random_state=42)
clf.fit(X_train, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(X_train, y_train)

predict_y = sig_clf.predict_proba(X_train)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(X_test)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
predicted_y =np.argmax(predict_y,axis=1)
print("Total number of data points :", len(predicted_y))
plot_confusion_matrix(y_test, predicted_y)
# Out:
# For values of alpha =  1e-05 The log loss is: 0.6605330481991829
# For values of alpha =  0.0001 The log loss is: 0.6605330481991829
# For values of alpha =  0.001 The log loss is: 0.6605330481991829
# For values of alpha =  0.01 The log loss is: 0.4894916668775639
# For values of alpha =  0.1 The log loss is: 0.5691813051709318
# For values of alpha =  1 The log loss is: 0.6394594474187788
# For values of alpha =  10 The log loss is: 0.6605330481991829
# For values of best alpha =  0.01 The train log loss is: 0.4859075653060736
# For values of best alpha =  0.01 The test log loss is: 0.4894916668775639
# Total number of data points : 15000

# %% [markdown]
# <h2> 4.6 XGBoost </h2>

# %%
import xgboost as xgb

# %%
depths = [3,4,5,7,9,12,15]
train_scores = []
test_scores = []
for i in depths:
    params = {}
    params['objective'] = 'binary:logistic'
    params['eval_metric'] = 'logloss'
    params['eta'] = 0.02
    params['max_depth'] = i


    py_evals_result = {}

    d_train = xgb.DMatrix(X_train, label=y_train)
    d_test = xgb.DMatrix(X_test, label=y_test)

    watchlist = [(d_train, 'train'), (d_test, 'valid')]

    #bst = xgb.train(params, d_train, 400, watchlist, early_stopping_rounds=20, maximize=False ,verbose_eval=10,feval=log_loss, evals_result=py_evals_result)
    bst = xgb.train(params, d_train, 400, watchlist, early_stopping_rounds=20, verbose_eval=10)

    xgdmat = xgb.DMatrix(X_train,y_train)
    predict_y = bst.predict(d_test)
    predict_y_tr = bst.predict(d_train)
    print('depth = ',i,'Train Score',log_loss(y_train, predict_y_tr),'test Score',log_loss(y_test, predict_y))
    test_scores.append(log_loss(y_test, predict_y))
    train_scores.append(log_loss(y_train, predict_y_tr))
    #print("The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# [0]	train-logloss:0.685667	valid-logloss:0.685687
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 20 rounds.
# [10]	train-logloss:0.621347	valid-logloss:0.621539
# [20]	train-logloss:0.574252	valid-logloss:0.574648
# [30]	train-logloss:0.538687	valid-logloss:0.539386
# [40]	train-logloss:0.510886	valid-logloss:0.511722
# [50]	train-logloss:0.489487	valid-logloss:0.490515
# [60]	train-logloss:0.472456	valid-logloss:0.473624
# [70]	train-logloss:0.458529	valid-logloss:0.459779
# [80]	train-logloss:0.447052	valid-logloss:0.448431
# [90]	train-logloss:0.437696	valid-logloss:0.439171
# [100]	train-logloss:0.429564	valid-logloss:0.431035
# [110]	train-logloss:0.422442	valid-logloss:0.423893
# [120]	train-logloss:0.416464	valid-logloss:0.41798
# [130]	train-logloss:0.411447	valid-logloss:0.413086
# [140]	train-logloss:0.406962	valid-logloss:0.40867
# [150]	train-logloss:0.403051	valid-logloss:0.40499
# [160]	train-logloss:0.399581	valid-logloss:0.401742
# [170]	train-logloss:0.396563	valid-logloss:0.398899
# [180]	train-logloss:0.39366	valid-logloss:0.39613
# [190]	train-logloss:0.391275	valid-logloss:0.393951
# [200]	train-logloss:0.388891	valid-logloss:0.391744
# [210]	train-logloss:0.386991	valid-logloss:0.390029
# [220]	train-logloss:0.385132	valid-logloss:0.388398
# [230]	train-logloss:0.383223	valid-logloss:0.386706
# [240]	train-logloss:0.381631	valid-logloss:0.385362
# [250]	train-logloss:0.380027	valid-logloss:0.384025
# [260]	train-logloss:0.378719	valid-logloss:0.382972
# [270]	train-logloss:0.37713	valid-logloss:0.381628
# [280]	train-logloss:0.375696	valid-logloss:0.380489
# [290]	train-logloss:0.374341	valid-logloss:0.379384
# [300]	train-logloss:0.373238	valid-logloss:0.378457
# [310]	train-logloss:0.371852	valid-logloss:0.37726
# [320]	train-logloss:0.370854	valid-logloss:0.376447
# [330]	train-logloss:0.369878	valid-logloss:0.375628
# [340]	train-logloss:0.368941	valid-logloss:0.37499
# [350]	train-logloss:0.36794	valid-logloss:0.374221
# [260]	train-logloss:0.360994	valid-logloss:0.369952
# [270]	train-logloss:0.359359	valid-logloss:0.368722
# [280]	train-logloss:0.357901	valid-logloss:0.367708
# [290]	train-logloss:0.356418	valid-logloss:0.366729
# [300]	train-logloss:0.354854	valid-logloss:0.365656
# [310]	train-logloss:0.353521	valid-logloss:0.364748
# [320]	train-logloss:0.352393	valid-logloss:0.36397
# [330]	train-logloss:0.351052	valid-logloss:0.363138
# [340]	train-logloss:0.349792	valid-logloss:0.362374
# [350]	train-logloss:0.348619	valid-logloss:0.36174
# [360]	train-logloss:0.347528	valid-logloss:0.361165
# [370]	train-logloss:0.346369	valid-logloss:0.360583
# [380]	train-logloss:0.345146	valid-logloss:0.359879
# [390]	train-logloss:0.343916	valid-logloss:0.359303
# [399]	train-logloss:0.342923	valid-logloss:0.358813
# The test log loss is: 0.3588133483942288

# %%
plot_confusion_matrix(y_test, np.round(predict_y))

# %%
accuracy_score(y_test, np.round(predict_y))
# Out:
# 0.8172

# %%
#https://xgboost.readthedocs.io/en/latest/python/python_api.html?highlight=get_score#xgboost.Booster.get_score
feature_important = bst.get_score(importance_type='gain')
keys = list(feature_important.keys())
values = list(feature_important.values())

data = pd.DataFrame(data=values, index=keys, columns=["score"]).sort_values(by = "score", ascending=True)
data.plot(kind='barh',figsize=(20,50))
plt.figure(figsize=(10,12))

# %% [markdown]
# # **Word2Vec Features**

# %%
data= pd.read_csv("final_features.csv",nrows=50000)
data_wv = pd.read_csv("Distance_Features.csv",nrows=50000)

# %%
data.head()
# Out:
#    Unnamed: 0  id  is_duplicate  ...        93_y        94_y       95_y
# 0           0   0             0  ...   99.282776   50.791731 -17.566246
# 1           1   1             0  ...  194.269546  128.207803  55.490061
# 2           2   2             0  ...   19.922719   21.266690  49.574858
# 3           3   3             0  ...  -14.231000    4.772115   7.711628
# 4           4   4             0  ...   22.118795   68.802072  21.025373
#
# [5 rows x 221 columns]

# %%
# after we read from sql table each entry was read it as a string
# we convert all the features into numaric before we apply any model
cols = list(data.columns)
for i in cols:
    data[i] = data[i].apply(pd.to_numeric)
    print(i)
# Out:
# Unnamed: 0
# id
# is_duplicate
# cwc_min
# cwc_max
# csc_min
# csc_max
# ctc_min
# ctc_max
# last_word_eq
# first_word_eq
# abs_len_diff
# mean_len
# token_set_ratio
# token_sort_ratio
# fuzz_ratio
# fuzz_partial_ratio
# longest_substr_ratio
# freq_qid1
# freq_qid2
# q1len
# q2len
# q1_n_words
# q2_n_words
# word_Common
# word_Total
# word_share
# freq_q1+q2
# freq_q1-q2
# 0_x
# 1_x
# 2_x
# 3_x
# 4_x
# 5_x
# 6_x
# 7_x
# 8_x
# 9_x
# 10_x
# 11_x
# 12_x
# 13_x
# 14_x
# 15_x
# 16_x
# 17_x
# 18_x
# 19_x
# 20_x
# 21_x
# 22_x
# 23_x
# 24_x
# 25_x
# 26_x
# 27_x
# 28_x
# 29_x
# 30_x
# 31_x
# 32_x
# 33_x
# 34_x
# 35_x
# 36_x
# 37_x
# 38_x
# 39_x
# 40_x
# 41_x
# 42_x
# 43_x
# 44_x
# 45_x
# 46_x
# 47_x
# 48_x
# 49_x
# 50_x
# 51_x
# 52_x
# 53_x
# 54_x
# 55_x
# 56_x
# 57_x
# 58_x
# 59_x
# 60_x
# 61_x
# 62_x
# 63_x
# 64_x
# 65_x
# 66_x
# 67_x
# 68_x
# 69_x
# 70_x
# 71_x
# 72_x
# 73_x
# 74_x
# 75_x
# 76_x
# 77_x
# 78_x
# 79_x
# 80_x
# 81_x
# 82_x
# 83_x
# 84_x
# 85_x
# 86_x
# 87_x
# 88_x
# 89_x
# 90_x
# 91_x
# 92_x
# 93_x
# 94_x
# 95_x
# 0_y
# 1_y
# 2_y
# 3_y
# 4_y
# 5_y
# 6_y
# 7_y
# 8_y
# 9_y
# 10_y
# 11_y
# 12_y
# 13_y
# 14_y
# 15_y
# 16_y
# 17_y
# 18_y
# 19_y
# 20_y
# 21_y
# 22_y
# 23_y
# 24_y
# 25_y
# 26_y
# 27_y
# 28_y
# 29_y
# 30_y
# 31_y
# 32_y
# 33_y
# 34_y
# 35_y
# 36_y
# 37_y
# 38_y
# 39_y
# 40_y
# 41_y
# 42_y
# 43_y
# 44_y
# 45_y
# 46_y
# 47_y
# 48_y
# 49_y
# 50_y
# 51_y
# 52_y
# 53_y
# 54_y
# 55_y
# 56_y
# 57_y
# 58_y
# 59_y
# 60_y
# 61_y
# 62_y
# 63_y
# 64_y
# 65_y
# 66_y
# 67_y
# 68_y
# 69_y
# 70_y
# 71_y
# 72_y
# 73_y
# 74_y
# 75_y
# 76_y
# 77_y
# 78_y
# 79_y
# 80_y
# 81_y
# 82_y
# 83_y
# 84_y
# 85_y
# 86_y
# 87_y
# 88_y
# 89_y
# 90_y
# 91_y
# 92_y
# 93_y
# 94_y
# 95_y

# %%
data_wv.head()
# Out:
#    cosine_distance  minkowski_distance  ...  euclidean_distance  canberra_distance
# 0         0.035691            0.148922  ...            0.267174          25.291822
# 1         0.196881            0.337001  ...            0.627505          38.468346
# 2         0.283908            0.415039  ...            0.753536          46.469070
# 3         0.903092            0.720832  ...            1.343944          69.049830
# 4         0.307654            0.431272  ...            0.784416          47.658501
#
# [5 rows x 5 columns]

# %%
data['cosine_distance']=data_wv['cosine_distance']
data['minkowski_distance']=data_wv['minkowski_distance']
data['jaccard_distance']=data_wv['jaccard_distance']
data['euclidean_distance']=data_wv['euclidean_distance']
data['canberra_distance']=data_wv['canberra_distance']

# %%
data.head()
# Out:
#    Unnamed: 0  id  ...  euclidean_distance  canberra_distance
# 0           0   0  ...            0.267174          25.291822
# 1           1   1  ...            0.627505          38.468346
# 2           2   2  ...            0.753536          46.469070
# 3           3   3  ...            1.343944          69.049830
# 4           4   4  ...            0.784416          47.658501
#
# [5 rows x 226 columns]

# %%
data.drop(data.index[0], inplace=True)
y_true = data['is_duplicate']
data.drop(['Unnamed: 0', 'id','is_duplicate'], axis=1, inplace=True)

# %%
data.head()
# Out:
#     cwc_min   cwc_max  ...  euclidean_distance  canberra_distance
# 1  0.799984  0.399996  ...            0.627505          38.468346
# 2  0.399992  0.333328  ...            0.753536          46.469070
# 3  0.000000  0.000000  ...            1.343944          69.049830
# 4  0.399992  0.199998  ...            0.784416          47.658501
# 5  0.666656  0.571420  ...            0.638471          42.253442
#
# [5 rows x 223 columns]

# %%
# https://stackoverflow.com/questions/7368789/convert-all-strings-in-a-list-to-int
y_true = list(map(int, y_true.values))

# %%
X_train,X_test, y_train, y_test = train_test_split(data, y_true, stratify=y_true, test_size=0.3)

# %%
print("Number of data points in train data :",X_train.shape)
print("Number of data points in test data :",X_test.shape)
# Out:
# Number of data points in train data : (34999, 223)
# Number of data points in test data : (15000, 223)

# %%
print("-"*10, "Distribution of output variable in train data", "-"*10)
train_distr = Counter(y_train)
train_len = len(y_train)
print("Class 0: ",int(train_distr[0])/train_len,"Class 1: ", int(train_distr[1])/train_len)
print("-"*10, "Distribution of output variable in test data", "-"*10)
test_distr = Counter(y_test)
test_len = len(y_test)
print("Class 0: ",int(test_distr[1])/test_len, "Class 1: ",int(test_distr[1])/test_len)
# Out:
# ---------- Distribution of output variable in train data ----------
# Class 0:  0.6270179147975656 Class 1:  0.37298208520243437
# ---------- Distribution of output variable in test data ----------
# Class 0:  0.373 Class 1:  0.373

# %%
# This function plots the confusion matrices given y_i, y_i_hat.
def plot_confusion_matrix(test_y, predict_y):
    C = confusion_matrix(test_y, predict_y)
    # C = 9,9 matrix, each cell (i,j) represents number of points of class i are predicted class j
    
    A =(((C.T)/(C.sum(axis=1))).T)
    #divid each element of the confusion matrix with the sum of elements in that column
    
    # C = [[1, 2],
    #     [3, 4]]
    # C.T = [[1, 3],
    #        [2, 4]]
    # C.sum(axis = 1)  axis=0 corresonds to columns and axis=1 corresponds to rows in two diamensional array
    # C.sum(axix =1) = [[3, 7]]
    # ((C.T)/(C.sum(axis=1))) = [[1/3, 3/7]
    #                           [2/3, 4/7]]

    # ((C.T)/(C.sum(axis=1))).T = [[1/3, 2/3]
    #                           [3/7, 4/7]]
    # sum of row elements = 1
    
    B =(C/C.sum(axis=0))
    #divid each element of the confusion matrix with the sum of elements in that row
    # C = [[1, 2],
    #     [3, 4]]
    # C.sum(axis = 0)  axis=0 corresonds to columns and axis=1 corresponds to rows in two diamensional array
    # C.sum(axix =0) = [[4, 6]]
    # (C/C.sum(axis=0)) = [[1/4, 2/6],
    #                      [3/4, 4/6]] 
    plt.figure(figsize=(20,4))
    
    labels = [1,2]
    # representing A in heatmap format
    cmap=sns.light_palette("blue")
    plt.subplot(1, 3, 1)
    sns.heatmap(C, annot=True, cmap=cmap, fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.title("Confusion matrix")
    
    plt.subplot(1, 3, 2)
    sns.heatmap(B, annot=True, cmap=cmap, fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.title("Precision matrix")
    
    plt.subplot(1, 3, 3)
    # representing B in heatmap format
    sns.heatmap(A, annot=True, cmap=cmap, fmt=".3f", xticklabels=labels, yticklabels=labels)
    plt.xlabel('Predicted Class')
    plt.ylabel('Original Class')
    plt.title("Recall matrix")
    
    plt.show()

# %%
# we need to generate 9 numbers and the sum of numbers should be 1
# one solution is to genarate 9 numbers and divide each of the numbers by their sum
# ref: https://stackoverflow.com/a/18662466/4084039
# we create a output array that has exactly same size as the CV data
predicted_y = np.zeros((test_len,2))
for i in range(test_len):
    rand_probs = np.random.rand(1,2)
    predicted_y[i] = ((rand_probs/sum(sum(rand_probs)))[0])
print("Log loss on Test Data using Random Model",log_loss(y_test, predicted_y, eps=1e-15))

predicted_y =np.argmax(predicted_y, axis=1)
plot_confusion_matrix(y_test, predicted_y)
# Out:
# Log loss on Test Data using Random Model 0.8863667300857813

# %%
alpha = [10 ** x for x in range(-5, 2)] # hyperparam for SGD classifier.


log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l2', loss='log', random_state=42)
    clf.fit(X_train, y_train)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(X_train, y_train)
    predict_y = sig_clf.predict_proba(X_test)
    log_error_array.append(log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, log_error_array,c='g')
for i, txt in enumerate(np.round(log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l2', loss='log', random_state=42)
clf.fit(X_train, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(X_train, y_train)

predict_y = sig_clf.predict_proba(X_train)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(X_test)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
predicted_y =np.argmax(predict_y,axis=1)
print("Total number of data points :", len(predicted_y))
plot_confusion_matrix(y_test, predicted_y)
# Out:
# For values of alpha =  1e-05 The log loss is: 0.6605330481991829
# For values of alpha =  0.0001 The log loss is: 0.46766821071537623
# For values of alpha =  0.001 The log loss is: 0.4717038241219789
# For values of alpha =  0.01 The log loss is: 0.4772674934691616
# For values of alpha =  0.1 The log loss is: 0.46294403427358244
# For values of alpha =  1 The log loss is: 0.48076605406170553
# For values of alpha =  10 The log loss is: 0.5086537418571563
# For values of best alpha =  0.1 The train log loss is: 0.45913624462671987
# For values of best alpha =  0.1 The test log loss is: 0.46294403427358244
# Total number of data points : 15000

# %%
alpha = [10 ** x for x in range(-5, 2)] # hyperparam for SGD classifier.


log_error_array=[]
for i in alpha:
    clf = SGDClassifier(alpha=i, penalty='l1', loss='hinge', random_state=42)
    clf.fit(X_train, y_train)
    sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
    sig_clf.fit(X_train, y_train)
    predict_y = sig_clf.predict_proba(X_test)
    log_error_array.append(log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
    print('For values of alpha = ', i, "The log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))

fig, ax = plt.subplots()
ax.plot(alpha, log_error_array,c='g')
for i, txt in enumerate(np.round(log_error_array,3)):
    ax.annotate((alpha[i],np.round(txt,3)), (alpha[i],log_error_array[i]))
plt.grid()
plt.title("Cross Validation Error for each alpha")
plt.xlabel("Alpha i's")
plt.ylabel("Error measure")
plt.show()


best_alpha = np.argmin(log_error_array)
clf = SGDClassifier(alpha=alpha[best_alpha], penalty='l1', loss='hinge', random_state=42)
clf.fit(X_train, y_train)
sig_clf = CalibratedClassifierCV(clf, method="sigmoid")
sig_clf.fit(X_train, y_train)

predict_y = sig_clf.predict_proba(X_train)
print('For values of best alpha = ', alpha[best_alpha], "The train log loss is:",log_loss(y_train, predict_y, labels=clf.classes_, eps=1e-15))
predict_y = sig_clf.predict_proba(X_test)
print('For values of best alpha = ', alpha[best_alpha], "The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
predicted_y =np.argmax(predict_y,axis=1)
print("Total number of data points :", len(predicted_y))
plot_confusion_matrix(y_test, predicted_y)
# Out:
# For values of alpha =  1e-05 The log loss is: 0.6605330481991829
# For values of alpha =  0.0001 The log loss is: 0.6605330481991829
# For values of alpha =  0.001 The log loss is: 0.6605330481991829
# For values of alpha =  0.01 The log loss is: 0.505558013340474
# For values of alpha =  0.1 The log loss is: 0.5887950052070416

# %%
depths = [3,4,5,7,9,12,15]
train_scores = []
test_scores = []
for i in depths:
    params = {}
    params['objective'] = 'binary:logistic'
    params['eval_metric'] = 'logloss'
    params['eta'] = 0.02
    params['max_depth'] = i


    py_evals_result = {}

    d_train = xgb.DMatrix(X_train, label=y_train)
    d_test = xgb.DMatrix(X_test, label=y_test)

    watchlist = [(d_train, 'train'), (d_test, 'valid')]

    #bst = xgb.train(params, d_train, 400, watchlist, early_stopping_rounds=20, maximize=False ,verbose_eval=10,feval=log_loss, evals_result=py_evals_result)
    bst = xgb.train(params, d_train, 400, watchlist, early_stopping_rounds=20, verbose_eval=10)

    xgdmat = xgb.DMatrix(X_train,y_train)
    predict_y = bst.predict(d_test)
    predict_y_tr = bst.predict(d_train)
    print('depth = ',i,'Train Score',log_loss(y_train, predict_y_tr),'test Score',log_loss(y_test, predict_y))
    test_scores.append(log_loss(y_test, predict_y))
    train_scores.append(log_loss(y_train, predict_y_tr))
    #print("The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# [0]	train-logloss:0.685606	valid-logloss:0.685728
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 20 rounds.
# [10]	train-logloss:0
params = {}
params['objective'] = 'binary:logistic'
params['eval_metric'] = 'logloss'
params['eta'] = 0.02
params['max_depth'] = 4

d_train = xgb.DMatrix(X_train, label=y_train)
d_test = xgb.DMatrix(X_test, label=y_test)

watchlist = [(d_train, 'train'), (d_test, 'valid')]

bst = xgb.train(params, d_train, 400, watchlist, early_stopping_rounds=20, verbose_eval=10)

xgdmat = xgb.DMatrix(X_train,y_train)
predict_y = bst.predict(d_test)
print("The test log loss is:",log_loss(y_test, predict_y, labels=clf.classes_, eps=1e-15))
# Out:
# [0]	train-logloss:0.684938	valid-logloss:0.684984
# Multiple eval metrics have been passed: 'valid-logloss' will be used for early stopping.
#
# Will train until valid-logloss hasn't improved in 20 rounds.
# [10]	train-logloss:0.615232	valid-logloss:0.61634
# [20]	train-logloss:0.563625	valid-logloss:0.565363
# [30]	train-logloss:0.52485	valid-logloss:0.527181
# [40]	train-logloss:0.495178	valid-logloss:0.497939
# [50]	train-logloss:0.471738	valid-logloss:0.474958
# [60]	train-logloss:0.45313	valid-logloss:0.456674
# [70]	train-logloss:0.438293	valid-logloss:0.442158
# [80]	train-logloss:0.426131	valid-logloss:0.430502
# [90]	train-logloss:0.416353	valid-logloss:0.420999
# [100]	train-logloss:0.408294	valid-logloss:0.413278
# [110]	train-logloss:0.401262	valid-logloss:0.406609
# [120]	train-logloss:0.395363	valid-logloss:0.401089
# [130]	train-logloss:0.39037	valid-logloss:0.396388
# [140]	train-logloss:0.386016	valid-logloss:0.392331
# [150]	train-logloss:0.382409	valid-logloss:0.389093
# [160]	train-logloss:0.379272	valid-logloss:0.386333
# [170]	train-logloss:0.376414	valid-logloss:0.383857
# [180]	train-logloss:0.373958	valid-logloss:0.381805
# [190]	train-logloss:0.371615	valid-logloss:0.379824
# [200]	train-logloss:0.36961	valid-logloss:0.378167
# [210]	train-logloss:0.367742	valid-logloss:0.376668
# [220]	train-logloss:0.366024	valid-logloss:0.375262
# [230]	train-logloss:0.364473	valid-logloss:0.374052
# [240]	train-logloss:0.362698	valid-logloss:0.372595
# [250]	train-logloss:0.360995	valid-logloss:0.371282
# [260]	train-logloss:0.359403	valid-logloss:0.370129
# [270]	train-logloss:0.35784	valid-logloss:0.369039
# [280]	train-logloss:0.356252	valid-logloss:0.367927
# [290]	train-logloss:0.354841	valid-logloss:0.366991
# [300]	train-logloss:0.35348	valid-logloss:0.366116
# [310]	train-logloss:0.352101	valid-logloss:0.365186
# [320]	train-logloss:0.350879	valid-logloss:0.36441
# [330]	train-logloss:0.349766	valid-logloss:0.36364
# [340]	train-logloss:0.348623	valid-logloss:0.362938
# [350]	train-logloss:0.347472	valid-logloss:0.362188
# [360]	train-logloss:0.346391	valid-logloss:0.361527
# [370]	train-logloss:0.345248	valid-logloss:0.360858
# [380]	train-logloss:0.344195	valid-logloss:0.360263
# [390]	train-logloss:0.343166	valid-logloss:0.359677
# [399]	train-logloss:0.342191	valid-logloss:0.359095
# The test log loss is: 0.3590947512730956

# %%
print("Accuracy : " ,accuracy_score(y_test, np.round(predict_y)))
# Out:
# Accuracy :  0.821

# %%
#bst.save_model('Quara.model')

# %% [markdown]
#  **We are improved by 1% by adding this features.**

# %%
plot_confusion_matrix(y_test, np.round(predict_y))

# %%
#https://xgboost.readthedocs.io/en/latest/python/python_api.html?highlight=get_score#xgboost.Booster.get_score
feature_important = bst.get_score(importance_type='gain')
keys = list(feature_important.keys())
values = list(feature_important.values())

data = pd.DataFrame(data=values, index=keys, columns=["score"]).sort_values(by = "score", ascending=True)
data.plot(kind='barh',figsize=(20,50))
plt.figure(figsize=(10,12))

# %%
data= pd.read_csv("final_features.csv",)
data_wv = pd.read_csv("Distance_Features.csv")

# %%
model_xgb = xgb.Booster()
model_xgb.load_model("Quara.model")
